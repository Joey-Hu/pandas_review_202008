# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %matplotlib inline

# %%
apple = pd.read_csv('../data/appl_1980_2014.csv')
apple.dtypes
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-55-b70d56299c6d> in <module>
# ----> 1 apple = pd.read_csv('../data/appl_1980_2014.csv')
#       2 apple.dtypes
#
# c:\programdata\anaconda3\envs\tfenv\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# c:\programdata\anaconda3\envs\tfenv\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# c:\programdata\anaconda3\envs\tfenv\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# c:\programdata\anaconda3\envs\tfenv\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# c:\programdata\anaconda3\envs\tfenv\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'../data/appl_1980_2014.csv' does not exist: b'../data/appl_1980_2014.csv'

# %%
apple['Date'] = pd.to_datetime(apple['Date'])
apple.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Volume                int64
# Adj Close           float64
# dtype: object

# %%
apple = apple.set_index('Date')
apple
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...           ...    ...    ...    ...        ...        ...
# 2009-02-05  92.77  97.25  92.62  96.46  187311600      13.17
# 2009-02-04  93.22  96.25  93.10  93.55  202105400      12.77
# 2009-02-03  91.92  93.38  90.28  92.98  149827300      12.70
# 2009-02-02  89.10  92.00  88.90  91.51  139561800      12.50
# 2009-01-30  92.60  93.62  90.01  90.13  162869700      12.00
#
# [1368 rows x 6 columns]

# %%
#  Is there any duplicate dates?
apple.index.is_unique
# Out:
# True

# %%
# Ops...it seems the index is from the most recent date. Make the first entry the oldest date
apple.sort_index(ascending=True)
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 2009-01-30  92.60  93.62  90.01  90.13  162869700      12.00
# 2009-02-02  89.10  92.00  88.90  91.51  139561800      12.50
# 2009-02-03  91.92  93.38  90.28  92.98  149827300      12.70
# 2009-02-04  93.22  96.25  93.10  93.55  202105400      12.77
# 2009-02-05  92.77  97.25  92.62  96.46  187311600      13.17
# ...           ...    ...    ...    ...        ...        ...
# 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
#
# [1368 rows x 6 columns]

# %%
# Get the last business day of each month
apple_month = apple.resample('BM').mean()
apple_month
# Out:
#                   Open        High         Low       Close        Volume  \
# Date
# 2009-01-30   92.600000   93.620000   90.010000   90.130000  1.628697e+08
# 2009-02-27   93.691053   95.892632   92.298947   94.074211  1.824665e+08
# 2009-03-31   96.926364   99.245455   95.530909   97.505000  1.752795e+08
# 2009-04-30  119.177143  121.274762  118.017143  120.020952  1.407343e+08
# 2009-05-29  127.774500  129.815000  125.931500  128.149000  1.182143e+08
# ...                ...         ...         ...         ...           ...
# 2014-03-31  533.593333  536.453810  530.070952  533.214286  5.954403e+07
# 2014-04-30  540.081905  544.349048  536.262381  541.074286  7.660787e+07
# 2014-05-30  601.301905  606.372857  598.332857  603.195714  6.828177e+07
# 2014-06-30  222.360000  224.084286  220.735714  222.658095  5.745506e+07
# 2014-07-31   94.294000   95.004000   93.488000   94.470000  4.218366e+07
#
#             Adj Close
# Date
# 2009-01-30  12.000000
# 2009-02-27  12.845789
# 2009-03-31  13.314545
# 2009-04-30  16.387619
# 2009-05-29  17.498000
# ...               ...
# 2014-03-31  75.750000
# 2014-04-30  76.867143
# 2014-05-30  86.058571
# 2014-06-30  91.885714
# 2014-07-31  94.470000
#
# [67 rows x 6 columns]

# %%
# What is the difference in days between the first day and the oldest
# (apple.index[0] - apple.index[-1]).days
(apple.index.max() - apple.index.min()).days
# Out:
# 1985

# %%
# How many months in the data we have?
apple_months = apple.resample('BM').mean()

len(apple_months.index)
# Out:
# 67

# %%
appl_open = apple['Adj Close'].plot(title = "Apple Stock")
fig = appl_open.get_figure()
fig.set_size_inches(13.5, 9)
